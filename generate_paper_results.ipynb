# %% [markdown]
# # Generate paper results
#
# This notebook will be the main entry point for running the numerical study and generating the figures and tables used in the paper. The simulation and analysis sections will be implemented in subsequent development passes.
